# %%
# Workflow of Machine Learning
## Data Ingestion ---> Data Cleaning and Preprocessing ---> Select ML Model ---->
## Model Training ---> Model Prediction ---> Calculate performance of Model.

# %%
## Data Cleanig and Preprocessing ---->
# Data ----> Divided into parts ---> x_train, x_test, y_train, y_test

# 1 + 1 = 2
# 2 + 2 = 4
# 3 + 2 = 5

## Machine (5 + 7) ----> ???   --- Prediction = 13
## 5+7 ---> x_test
## 12 ---> y_test
## 13 ---> y_pred

## Machine (y_pred, y_test)

# %%
## How we divide the data???
import pandas as pd

# %%
df = pd.read_csv('/content/covid_toy.csv')
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever'] = df['fever'].fillna(df['fever'].mean())

# %%
x = df.drop(columns = ['has_covid'])                   ## Input or independent Data
x.shape
# Out:
# (100, 5)

# %%
y = df['has_covid']                 ## Target or dependent data
y.shape
# Out:
# (100,)

# %% [markdown]
# ## **Importing Scikit-Learn**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size = 0.2,
                                                    random_state=42)

# %%
print("Total Data Shape : ", df.shape)
print("--------------------------------")
print("Input Data Shape : ", x.shape)
print("X Train Data Shape : ", x_train.shape)
print("X Test Data Shape : ", x_test.shape)
print("--------------------------------")
print("Target Data Shape : ", y.shape)
print("Y Train Data Shape : ", y_train.shape)
print("Y Test Data Shape : ", y_test.shape)
# Out:
# Total Data Shape :  (100, 6)
# --------------------------------
# Input Data Shape :  (100, 5)
# X Train Data Shape :  (80, 5)
# X Test Data Shape :  (20, 5)
# --------------------------------
# Input Data Shape :  (100,)
# Y Train Data Shape :  (80,)
# Y Test Data Shape :  (20,)

# %%
df(100,6) = x(100,5) + y(100,1)

# %% [markdown]
# ## Dividing Another Data

# %%
df = pd.read_csv('/content/Customer_Call.xlsx - Call List.csv')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID           0
# First_Name           0
# Last_Name            1
# Phone_Number         2
# Address              0
# Paying Customer      0
# Do_Not_Contact       4
# Not_Useful_Column    0
# dtype: int64

# %%
df['Phone_Number'] = df['Phone_Number'].fillna('N/A')
df['Do_Not_Contact'] = df['Do_Not_Contact'].fillna('Not Mentioned')

# %%
x = df.drop(columns = ['Not_Useful_Column'])
x.shape
# Out:
# (21, 7)

# %%
y = df['Not_Useful_Column']
y.shape
# Out:
# (21,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state = 21)

# %%
print("Total Data Shape : ", df.shape)
print("--------------------------------")
print("Input Data Shape : ", x.shape)
print("X Train Data Shape : ", x_train.shape)
print("X Test Data Shape : ", x_test.shape)
print("--------------------------------")
print("Target Data Shape : ", y.shape)
print("Y Train Data Shape : ", y_train.shape)
print("Y Test Data Shape : ", y_test.shape)
# Out:
# Total Data Shape :  (21, 8)
# --------------------------------
# Input Data Shape :  (21, 7)
# X Train Data Shape :  (16, 7)
# X Test Data Shape :  (5, 7)
# --------------------------------
# Target Data Shape :  (21,)
# Y Train Data Shape :  (16,)
# Y Test Data Shape :  (5,)

# %%
df = pd.read_csv('/content/titanic - titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Cabin'] = df['Cabin'].fillna('Not Mentioned')
df['Fare'] = df['Fare'].fillna(df['Fare'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
x = df.drop(columns = ['Survived'])
x.shape
# Out:
# (418, 11)

# %%
y = df['Survived']
y.shape
# Out:
# (418,)

# %%
print("Total Data Shape : ", df.shape)
print("--------------------------------")
print("Input Data Shape : ", x.shape)
print("X Train Data Shape : ", x_train.shape)
print("X Test Data Shape : ", x_test.shape)
print("--------------------------------")
print("Target Data Shape : ", y.shape)
print("Y Train Data Shape : ", y_train.shape)
print("Y Test Data Shape : ", y_test.shape)
# Out:
# Total Data Shape :  (418, 12)
# --------------------------------
# Input Data Shape :  (418, 11)
# X Train Data Shape :  (16, 7)
# X Test Data Shape :  (5, 7)
# --------------------------------
# Target Data Shape :  (418,)
# Y Train Data Shape :  (16,)
# Y Test Data Shape :  (5,)
