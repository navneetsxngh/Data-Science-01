# %% [markdown]
# ## Logging with Multiple Loggers

# %%
import logging

## Create a Logger for module 1
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

## Create a logger for module 2
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

## Config Logging Settings
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
)

# %%
## Log Message with different loggers
logger1.debug("This is a debug message for module1")
logger2.warning("This is a warning message for module2")

logger2.error("This is an Error Message")
# Out:
# 2026-01-03 08:36:43 - module1 - DEBUG - This is a debug message for module1
# 2026-01-03 08:36:43 - module2 - WARNING - This is a warning message for module2
# 2026-01-03 08:36:43 - module2 - ERROR - This is an Error Message
